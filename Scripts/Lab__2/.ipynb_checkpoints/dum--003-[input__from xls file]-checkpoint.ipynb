# %%
# page 3

#Example 1:  The upward velocity of a rocket is given at three different times in Table 1

# %%
import pandas as pd
import numpy as np
import scipy

# %%
xls=pd.ExcelFile("/media/ashraful/New Volume/labfiles/data.xls")

print xls

sheetx=xls.parse(0)

print sheetx


var1=sheetx['aa']
var2=sheetx['bb']
var3=sheetx['cc']
var4=sheetx['dd']

#print ((var1), '\n ',var2, ' \n ',var3)


c=np.array([var1,var2,var3], dtype='float')

c= c.T
d=np.array(var4, dtype='float')
d=d.T
# Out:
# <pandas.io.excel.ExcelFile object at 0x7f52d17c0d50>
#     aa  bb  cc     dd
# 0   25   5   1  106.8
# 1   64   8   1  177.2
# 2  144  12   1  279.2

# %%
import numpy as np
#A = np.array([[25,5,1], [64,8,1], [144,12,1]], dtype='float')
#b = np.array([106.8, 177.2, 279.2])
A=c
b=d
x1=A
y1=b
#print b
#print b.reshape(-1, 1)
Ab = np.hstack([A, b.reshape(-1, 1)])

#print Ab
n = len(b)
#print n
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = a[i] / b[i]
        Ab[j] = a - m * b
        #print 'j '," = ",j, b," = ",   m

print "##  \n  "
print Ab
for i in range(n - 1, -1, -1):
    #print Ab[i],"  /  " , Ab[i, i] ," idx" ,i,i
    Ab[i] = Ab[i] / Ab[i, i]
    a = Ab[i]
    



    for j in range(i - 1, -1, -1):
        b = Ab[j]
        m = a[i] / b[i]
        Ab[j] = (a - m * b)
    
print "identical " ,"  \n  "
print Ab

x = Ab[:, 3]

print x

z=[]
for data in x:
    z.append((data))
    
print "solution is  \n  ",z
# Out:
# ##
#
# [[2.50000000e+01 5.00000000e+00 1.00000000e+00 1.06800000e+02]
#  [0.00000000e+00 1.87500000e+00 6.09375000e-01 3.75812500e+01]
#  [0.00000000e+00 0.00000000e+00 7.81250000e-02 8.48214286e-02]]
# identical
#
# [[ 1.         -0.         -0.          0.29047619]
#  [-0.          1.         -0.         19.69047619]
#  [ 0.          0.          1.          1.08571429]]
# [ 0.29047619 19.69047619  1.08571429]
# solution is
#    [0.2904761904761912, 19.690476190476183, 1.08571428571431]

# %%
print z

t=float(input("enter the value of t "))
y=z[0]*t*t+z[1]*t+z[2]

print y
# Out:
# [0.2904761904761912, 19.690476190476183, 1.08571428571431]
# enter the value of t 5
# 106.8

# %%
# ex 2 naive Gausseliminationto solve
#page 6

# %%
xls=pd.ExcelFile("/media/ashraful/New Volume/labfiles/data (copy).xls")

print xls

sheetx=xls.parse(0)

print sheetx


var1=sheetx['aa']
var2=sheetx['bb']
var3=sheetx['cc']
var4=sheetx['dd']

#print ((var1), '\n ',var2, ' \n ',var3)


c=np.array([var1,var2,var3], dtype='float')

c= c.T
d=np.array(var4, dtype='float')
d=d.T
t=c
b=d
# Out:
# <pandas.io.excel.ExcelFile object at 0x7f52d1758d90>
#    aa      bb  cc      dd
# 0  20  15.000  10  45.000
# 1  -3  -2.249   7   1.751
# 2   5   1.000   3   9.000

# %%
#import linalg package of the SciPy module for the LU decomp
import scipy.linalg as linalg 
#import NumPy
import numpy as np


#t=np.array([[20,15,10],[-3,-2.249,7],[5,1,3]])
#b=np.array([45,1.751,9])

Ab = np.hstack([t, b.reshape(-1, 1)])
A=Ab
#now we want to see how A has been factorized, P is the so called Permutation matrix
P, L, U = scipy.linalg.lu(A) 


print U


u=U


i3=1/(u[2][2]/u[2][3])

print i3

i21= u[1][3]-(u[1][2])*i3
i2=i21/u[1][1]
print i2

i11=u[0][3]-u[0][2]*i3-i2*u[0][1]

i1=i11/u[0][0]

print i1
# Out:
# [[20.         15.         10.         45.        ]
#  [ 0.         -2.75        0.5        -2.25      ]
#  [ 0.          0.          8.50018182  8.50018182]]
# 1.0
# 1.0
# 1.0

# %%
print c
# Out:
# [[20.    15.    10.   ]
#  [-3.    -2.249  7.   ]
#  [ 5.     1.     3.   ]]

# %%
#Find the LUdecomposition of the 
# page 10 exm 1

# %%
xls=pd.ExcelFile("/media/ashraful/New Volume/labfiles/data 1.xlsx")

print xls

sheetx=xls.parse(0)

#print sheetx


var1=sheetx['aa']
var2=sheetx['bb']
var3=sheetx['cc']
#var4=sheetx['dd']

#print ((var1), '\n ',var2, ' \n ',var3)


c=np.array([var1,var2,var3], dtype='float')

c= c.T
#d=np.array(var4, dtype='float')
#d=d.T
t=c
#b=d
print t
np.save('mm', t)
Ab=t
# Out:
# <pandas.io.excel.ExcelFile object at 0x7f52d17c0b50>
# [[ 25.   5.   1.]
#  [ 64.   8.   1.]
#  [144.  12.   1.]]

# %%
import numpy as np


#Ab=np.array([[25,5,1], [64,8,1], [144,12,1]],dtype='float')
np.save('d1', Ab) 
aaa=Ab
n = len(Ab)
#print n
me=[]
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = float(a[i] / b[i])
        me.append(1/m)
        Ab[j] = b - (1/m) * a
        #print 'j '," = ",j, b," = ",   m

print "upper  \n  "
print Ab
print me


ccc=Ab
np.save('d2', Ab) 

#for i in range(n):
#    for j in range(n):
#       print i,j
 #       print Ab[i][j]
        
k=0            
for i in range(n):
    for j in range(n):
        if (i > j) :
            ccc[i][j]=me[k]
            k=k+1
        else:
            continue
#print ccc 

for i in range(n):
    for j in range(n):
        if (i == j) :
            ccc[i][j]=1
            
        else:
            continue
        
            
       
            
#print ccc

for i in range(n):
    for j in range(n):
        if (i < j) :
            ccc[i][j]=0
            
        else:
            continue
print " lower is   \n " ,ccc 

np.save('d3', ccc) 

a1 = np.load('d1.npy')                                   
a2 = np.load('d2.npy')
a3=np.load('d3.npy')
print type(a3)
# Out:
# upper
#
# [[25.    5.    1.  ]
#  [ 0.   -4.8  -1.56]
#  [ 0.    0.    0.7 ]]
# [2.56, 5.76, 3.4999999999999987]
#  lower is
#   [[1.   0.   0.  ]
#  [2.56 1.   0.  ]
#  [5.76 3.5  1.  ]]
# <type 'numpy.ndarray'>

# %%
#print a1
print a2
print a3
print  np.matmul(a3,a2)
# Out:
# [[25.    5.    1.  ]
#  [ 0.   -4.8  -1.56]
#  [ 0.    0.    0.7 ]]
# [[1.   0.   0.  ]
#  [2.56 1.   0.  ]
#  [5.76 3.5  1.  ]]
# [[ 25.   5.   1.]
#  [ 64.   8.   1.]
#  [144.  12.   1.]]

# %% [markdown]
# page 11
# Example 2UsetheLUdecomposition method to
# solve the following simultaneous linear equations

# %%
xls=pd.ExcelFile("/media/ashraful/New Volume/labfiles/data1 (copy).xlsx")

print xls

sheetx=xls.parse(0)

print sheetx


var1=sheetx['aa']
var2=sheetx['bb']
var3=sheetx['cc']
var4=sheetx['dd']

#print ((var1), '\n ',var2, ' \n ',var3)


c=np.array([var1,var2,var3], dtype='float')

c= c.T
d=np.array(var4, dtype='float')
d=d.T
t=c
b=d
np.save('r1',b)
# Out:
# <pandas.io.excel.ExcelFile object at 0x7f52d10f05d0>
#     aa  bb  cc     dd
# 0   25   5   1  106.8
# 1   64   8   1  177.2
# 2  144  12   1  279.2

# %%
import numpy as np
Ab=t
#Ab=np.array([[25,5,1], [64,8,1], [144,12,1]],dtype='float')
np.save('d1', Ab) 
aaa=Ab
n = len(Ab)
#print n
me=[]
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = float(a[i] / b[i])
        me.append(1/m)
        Ab[j] = b - (1/m) * a
        #print 'j '," = ",j, b," = ",   m

print "upper  \n  "
print Ab
print me


ccc=Ab
np.save('d2', Ab) 

#for i in range(n):
#    for j in range(n):
#       print i,j
 #       print Ab[i][j]
        
k=0            
for i in range(n):
    for j in range(n):
        if (i > j) :
            ccc[i][j]=me[k]
            k=k+1
        else:
            continue
#print ccc 

for i in range(n):
    for j in range(n):
        if (i == j) :
            ccc[i][j]=1
            
        else:
            continue
        
            
       
            
#print ccc

for i in range(n):
    for j in range(n):
        if (i < j) :
            ccc[i][j]=0
            
        else:
            continue
print " lower is   \n " ,ccc 

np.save('d3', ccc) 

a1 = np.load('d1.npy')                                   
a2 = np.load('d2.npy')
a3=np.load('d3.npy')
# Out:
# upper
#
# [[25.    5.    1.  ]
#  [ 0.   -4.8  -1.56]
#  [ 0.    0.    0.7 ]]
# [2.56, 5.76, 3.4999999999999987]
#  lower is
#   [[1.   0.   0.  ]
#  [2.56 1.   0.  ]
#  [5.76 3.5  1.  ]]

# %%
L=a3
b=np.load('r1.npy') 
c=b
print c
# Out:
# [106.8 177.2 279.2]

# %%
LU = np.linalg.solve(L,c) 
x=LU
for d in LU:
    print d
# Out:
# 106.80000000000001
# -96.20799999999998
# 0.7599999999998379

# %%
##final solution 

LU = np.linalg.solve(a2,x) 
p=LU
for d in LU:
    print d
# Out:
# 0.29047619047618584
# 19.69047619047626
# 1.0857142857140567

# %% [markdown]
# page 13
# Example 3Use LUdecomposition to find the inverse o

# %%
b=np.load('mm.npy') 
c=b
print c
# Out:
# [[ 25.   5.   1.]
#  [ 64.   8.   1.]
#  [144.  12.   1.]]

# %%
import numpy as np
Ab=c
#Ab=np.array([[25,5,1], [64,8,1], [144,12,1]],dtype='float')
np.save('d1', Ab) 
aaa=Ab
n = len(Ab)
#print n
me=[]
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = float(a[i] / b[i])
        me.append(1/m)
        Ab[j] = b - (1/m) * a
        #print 'j '," = ",j, b," = ",   m

print "upper  \n  "
print Ab
print me


ccc=Ab
np.save('d2', Ab) 

#for i in range(n):
#    for j in range(n):
#       print i,j
 #       print Ab[i][j]
        
k=0            
for i in range(n):
    for j in range(n):
        if (i > j) :
            ccc[i][j]=me[k]
            k=k+1
        else:
            continue
#print ccc 

for i in range(n):
    for j in range(n):
        if (i == j) :
            ccc[i][j]=1
            
        else:
            continue
        
            
       
            
#print ccc

for i in range(n):
    for j in range(n):
        if (i < j) :
            ccc[i][j]=0
            
        else:
            continue
print " lower is   \n " ,ccc 

np.save('d3', ccc) 

a1 = np.load('d1.npy')                                   
a2 = np.load('d2.npy')
a3=np.load('d3.npy')
# Out:
# upper
#
# [[25.    5.    1.  ]
#  [ 0.   -4.8  -1.56]
#  [ 0.    0.    0.7 ]]
# [2.56, 5.76, 3.4999999999999987]
#  lower is
#   [[1.   0.   0.  ]
#  [2.56 1.   0.  ]
#  [5.76 3.5  1.  ]]

# %%
##final mergged block  

b=np.load('mm.npy') 
c=b
#print c
import numpy as np
Ab=c
#Ab=np.array([[25,5,1], [64,8,1], [144,12,1]],dtype='float')
np.save('d1', Ab) 
aaa=Ab
n = len(Ab)
#print n
me=[]
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = float(a[i] / b[i])
        me.append(1/m)
        Ab[j] = b - (1/m) * a
        #print 'j '," = ",j, b," = ",   m

#print "upper  \n  "
#print Ab
#print me


ccc=Ab
np.save('d2', Ab) 

#for i in range(n):
#    for j in range(n):
#       print i,j
 #       print Ab[i][j]
        
k=0            
for i in range(n):
    for j in range(n):
        if (i > j) :
            ccc[i][j]=me[k]
            k=k+1
        else:
            continue
#print ccc 

for i in range(n):
    for j in range(n):
        if (i == j) :
            ccc[i][j]=1
            
        else:
            continue
        
            
       
            
#print ccc

for i in range(n):
    for j in range(n):
        if (i < j) :
            ccc[i][j]=0
            
        else:
            continue
#print " lower is   \n " ,ccc 

np.save('d3', ccc) 

a1 = np.load('d1.npy')                                   
a2 = np.load('d2.npy')
a3=np.load('d3.npy')


x=[1,0,0]


LU = np.linalg.solve(a3,x) 
p=LU
#for d in LU:
 #   print d
    
    
    
##final solution 

LU = np.linalg.solve(a2,p) 
p1=LU
for d in LU:
    print d
    
    
    
print "#################   \n \n \n "
    
    
import numpy as np

Ab=np.array([[25,5,1], [64,8,1], [144,12,1]],dtype='float')
np.save('d1', Ab) 
aaa=Ab
n = len(Ab)
#print n
me=[]
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = float(a[i] / b[i])
        me.append(1/m)
        Ab[j] = b - (1/m) * a
        #print 'j '," = ",j, b," = ",   m

#print "upper  \n  "
#print Ab
#print me


ccc=Ab
np.save('d2', Ab) 

#for i in range(n):
#    for j in range(n):
#       print i,j
 #       print Ab[i][j]
        
k=0            
for i in range(n):
    for j in range(n):
        if (i > j) :
            ccc[i][j]=me[k]
            k=k+1
        else:
            continue
#print ccc 

for i in range(n):
    for j in range(n):
        if (i == j) :
            ccc[i][j]=1
            
        else:
            continue
        
            
       
            
#print ccc

for i in range(n):
    for j in range(n):
        if (i < j) :
            ccc[i][j]=0
            
        else:
            continue
#print " lower is   \n " ,ccc 

np.save('d3', ccc) 

a1 = np.load('d1.npy')                                   
a2 = np.load('d2.npy')
a3=np.load('d3.npy')


x=[0,1,0]


LU = np.linalg.solve(a3,x) 
p=LU
#for d in LU:
 #   print d
    
    
    
##final solution 

LU = np.linalg.solve(a2,p) 
p2=LU
for d in LU:
    print d
    
print "#################   \n \n \n "




import numpy as np

Ab=np.array([[25,5,1], [64,8,1], [144,12,1]],dtype='float')
np.save('d1', Ab) 
aaa=Ab
n = len(Ab)
#print n
me=[]
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = float(a[i] / b[i])
        me.append(1/m)
        Ab[j] = b - (1/m) * a
        #print 'j '," = ",j, b," = ",   m

#print "upper  \n  "
#print Ab
#print me


ccc=Ab
np.save('d2', Ab) 

#for i in range(n):
#    for j in range(n):
#       print i,j
 #       print Ab[i][j]
        
k=0            
for i in range(n):
    for j in range(n):
        if (i > j) :
            ccc[i][j]=me[k]
            k=k+1
        else:
            continue
#print ccc 

for i in range(n):
    for j in range(n):
        if (i == j) :
            ccc[i][j]=1
            
        else:
            continue
        
            
       
            
#print ccc

for i in range(n):
    for j in range(n):
        if (i < j) :
            ccc[i][j]=0
            
        else:
            continue
#print " lower is   \n " ,ccc 

np.save('d3', ccc) 

a1 = np.load('d1.npy')                                   
a2 = np.load('d2.npy')
a3=np.load('d3.npy')


x=[0,0,1]


LU = np.linalg.solve(a3,x) 
p=LU
#for d in LU:
 #   print d
    
    
    
##final solution 

LU = np.linalg.solve(a2,p) 
p3=LU
for d in LU:
    print d
    


print "#################   \n \n \n "
zz=np.array([[p1],[p2],[p3]])
fm=zz.T


print fm
print "#################   \n \n \n "
print a1
print "#################   \n \n \n "
c=np.matmul(fm,a1)
# Out:
# 0.0476190476190477
# -0.952380952380954
# 4.571428571428577
# #################
#
#
#
# -0.08333333333333356
# 1.4166666666666698
# -5.00000000000001
# #################
#
#
#
# 0.0357142857142858
# -0.46428571428571536
# 1.428571428571432
# #################
#
#
#
# [[[ 0.04761905 -0.08333333  0.03571429]]
#
#  [[-0.95238095  1.41666667 -0.46428571]]
#
#  [[ 4.57142857 -5.          1.42857143]]]
# #################
#
#
#
# [[ 25.   5.   1.]
#  [ 64.   8.   1.]
#  [144.  12.   1.]]
# #################

# %% [markdown]
# page 17
# Example 1The upward velocity of a rocket is given at three different time

# %%
xls=pd.ExcelFile("/media/ashraful/New Volume/labfiles/data (another copy).xls")

print xls

sheetx=xls.parse(0)

var1=sheetx['aa']


print (var1)
c=np.array(var1, dtype='float')

#c= c.T
print c
# Out:
# <pandas.io.excel.ExcelFile object at 0x7f52d10f0ad0>
# 0      3.672
# 1     -7.851
# 2   -155.360
# Name: aa, dtype: float64
# [   3.672   -7.851 -155.36 ]

# %%
inx=c
#print inx[0],inx[1],inx[2]
a1=inx[0]
a2=inx[1]
a3=inx[2]

# %%
#a1,a2,a3=3.6720,-7.8510,-155.36
n=5
p=1
while p <= n:
    m=[]
    
    print "iteration is ",p
    
    m.append(a1)
    m.append(a2)
    m.append(a3)
    a1=(106.8-5*a2-a3)/25
    a2=(177.2-64*a1-a3)/8
    a3=(279.2-144*a1-12*a2)
    
    print  p," th data solution is  ",a1,a2,a3
    
    print " \n "
    ea1=abs((a1-m[0])/(a1*.01))
    ea2=abs((a2-m[1])/(a2*.01))
    ea3=abs((a3-m[2])/(a3*.01))
    print p, " th iter error is ",ea1,ea2,ea3
    
    p=p+1
    
    print " \n  \n"
# Out:
# iteration is  1
# 1  th data solution is   12.056600000000001 -54.88280000000002 -798.3568
#
#
# 1  th iter error is  69.54365243932783 85.69497183088326 80.54002922001791
#
#
#
# iteration is  2
# 2  th data solution is   47.182832000000005 -255.51805600000006 -3448.9111360000006
#
#
# 2  th iter error is  74.44706159223337 78.52096996229494 76.85191735830215
#
#
#
# iteration is  3
# 3  th data solution is   193.33205664000005 -1093.3925611200002 -14439.905422720003
#
#
# 3  th iter error is  75.59492573553995 76.6307120529278 76.11541741420673
#
#
#
# iteration is  4
# 4  th data solution is   800.5467291328002 -4577.235655222402 -60072.701132454415
#
#
# 4  th iter error is  75.84999730753646 76.11238215641153 75.96261671190474
#
#
#
# iteration is  5
# 5  th data solution is   3322.6271763426566 -19049.77976918445 -249581.75616312912
#
#
# 5  th iter error is  75.90621256478155 75.97223846846414 75.93065212138731

# %% [markdown]
# page 20
# example --2

# %%
xls=pd.ExcelFile("/media/ashraful/New Volume/labfiles/data (3rd copy).xlsx")

print xls

sheetx=xls.parse(0)

var1=sheetx['aa']


print (var1)
c=np.array(var1, dtype='float')

#c= c.T
print c
inx=c
#print inx[0],inx[1],inx[2]
a1=inx[0]
a2=inx[1]
a3=inx[2]
# Out:
# <pandas.io.excel.ExcelFile object at 0x7f52d10f0b10>
# 0    1
# 1    0
# 2    1
# Name: aa, dtype: int64
# [1. 0. 1.]

# %%
#x=np.array([1,0,1],dtype='float')
#print inx[0],inx[1],inx[2]
#a1=x[0]
#a2=x[1]
#a3=x[2]
#a1,a2,a3=1.0000,0.0000,1.000
#a1=float((1-3*a2+5*a3)/12)
#a2=(28-a1-3*a3)/5
#a3=(76-3*a1-7*a2)/13
print a1,a2,a3
# Out:
# 1.0 0.0 1.0

# %%
n=5
p=1
while p <= n:
    m=[]
    
    print "iteration is ",p
    
    m.append(a1)
    m.append(a2)
    m.append(a3)
    a1=(1-3*a2+5*a3)/12
    a2=(28-a1-3*a3)/5
    a3=(76-3*a1-7*a2)/13
    
    print  p," th data solution is  ",a1,a2,a3
    
    print " \n "
    ea1=abs((a1-m[0])/(a1*.01))
    ea2=abs((a2-m[1])/(a2*.01))
    ea3=abs((a3-m[2])/(a3*.01))
    print p, " th iter error is ",ea1,ea2,ea3
    
    p=p+1
    
    print " \n  \n"
# Out:
# iteration is  1
# 1  th data solution is   0.5 4.9 3.092307692307692
#
#
# 1  th iter error is  100.0 100.0 67.66169154228855
#
#
#
# iteration is  2
# 2  th data solution is   0.14679487179487158 3.7152564102564107 3.811755424063116
#
#
# 2  th iter error is  240.61135371179085 31.888608992718858 18.87444633025624
#
#
#
# iteration is  3
# 3  th data solution is   0.7427506574621955 3.164396614069691 3.9708439791635053
#
#
# 3  th iter error is  80.23631883458236 17.408051624675004 4.006416669483518
#
#
#
# iteration is  4
# 4  th data solution is   0.946752504467371 3.028143111608423 3.997133900410687
#
#
# 4  th iter error is  21.54753708520095 4.499572755955247 0.6577193034359122
#
#
#
# iteration is  5
# 5  th data solution is   0.9917700139356805 3.0033656569664515 4.0000869507252155
#
#
# 5  th iter error is  4.539107740277883 0.8249896107221893 0.07382465308642645
