# %% [markdown]
# <img src="img/prb__1__1.png">

# %%
import statistics 
import math


file = open('1st1.txt', 'r')
fa=[]
for line in file.readlines():
    fname = line.rstrip().split(',') 
    

for e in fname:
    fa.append(float(e))
c=(fname)
a= (' '.join((fname)))


print fa



#  Arithmetic mean
s=0
for data in fa:
    s=s+data
#print s
#print len(fa)
c=s/len(fa)
print "arithmetic mean is ",c





def harmonicMean(arr, n) : 
    
    # Declare sum variables and  
    # initialize with zero. 
    sm = 0
    for i in range(0, n) : 
        sm = sm + (1) / arr[i]; 
   
    return n / sm 
  
  
# Driver code 
arr = fa; 
n = len(arr) 
print("harmonic mean is",harmonicMean(arr, n)) 




def geometricMean(arr, n) : 
      
    # declare product variable and 
    # initialize it to 1. 
    product = 1
      
    # Compute the product of all the 
    # elements in the array. 
    for i in range(0,n) : 
        product = product * arr[i] 
   
    # compute geometric mean through  
    # formula pow(product, 1/n) and 
    # return the value to main function. 
    gm = (float)(math.pow(product, (1 / n))) 
    return (float)(gm) 
      
      
# Driver function 
arr = fa 
n = len(arr) 
  
# to print 6 digits after decimal 
c=(geometricMean(arr, n))

print "geometric mean %f"%c



print("Grouped Median of the median is %s "%(statistics.median_grouped(fa)))




def SD(numList):
    cntN = len(numList)
    avgVal = float(sum(numList))/cntN
    return (sum((i-avgVal)**2 for i in numList)/(cntN))**0.5
sd=SD(fa)
vai=(sd)**2
print "standard deviation is ",sd





def all_modes(l):
    d = {}
    for c in l:
        if c not in d:
            d[c] = 1
        else:
            d[c] = d[c] + 1

    count_max = max([v for v in d.itervalues()])
    mode_list = [k for k,v in d.iteritems() if v == count_max]

    #return (mode_list, count_max)
    return (mode_list)

print "mode is " ,all_modes(fa)




def moment(data, k):
  data_mean = sum(data)/len(data)
  return sum((x-data_mean)**k for x in data)/len(data)



def moment(data, k,va):
  data_mean = va
  return sum((x-data_mean)**k for x in data)/len(data)
value=5
k=1
print "moment about a value with %d th order"%k,moment(fa,k,value)
# Out:
# [5.0, 12.0, 5.0, 7.0, 21.0, 23.0, 24.0, 15.0, 8.0, 22.0, 23.0, 9.0, 11.0, 18.0, 22.0, 21.0, 19.0, 3.0, 4.0, 20.0]
# arithmetic mean is  14.6
# ('harmonic mean is', 9.633130939324978)
# geometric mean 1.000000
# Grouped Median of the median is 17.5
# standard deviation is  7.29657453878
# mode is  [5.0, 21.0, 22.0, 23.0]
# moment about a value with 1 th order 9.6

# %% [markdown]
# <img src="img/prb__1__2.png">

# %%
#f='//media//ashraful//New Volume//labfiles//text5.txt'
f='1st2.txt'
file = open(f, 'r')

with open(f) as fl:
    #print zip(*[line.split() for line in fl])[0]
    da= zip(*[line.split() for line in fl])[0]
with open(f) as fl:
    #print zip(*[line.split() for line in fl])[1]
    ta=zip(*[line.split() for line in fl])[1]
    
    
pr=[]
for i in da:
    a=i.split("-")
    pr.append(float(a[0]))
    pr.append(float(a[1]))
    
    
    
    
    
    
mark=[]
i=0
while(i<(len(pr))):
    k=pr[i]+pr[i+1]
    k=k/2
    mark.append(k)
    i=i+2
lower_lim=pr[0] 
print lower_lim






count=[]
for i in ta:
    
    count.append(float(i))

    
    
    

print mark  #mid values 
print count #freq



from math import *



i=0
s=0
gm1=0

while(i<len(mark)):
    s=s+mark[i]*count[i]
    gm1=gm1+log(mark[i])*count[i]
  
    i+=1
gm2=gm1/sum(count)
gmf=exp(gm2)
am=s/sum(count) 
#print gm2 

print "geometric mean is ",gmf
print "arthic. mean is ", am 



tf=sum(count)
print "total frequency ",sum(count)



i=0
s=0
while(i<len(mark)):
    s=s+(count[i]/mark[i])
    
    i+=1
#print s
hm=tf/s
print "harmonic mean is ",hm



#cumulative freq...


i=0
cu=[]
while(i<len(count)):
    if i == 0:
        k=count[i]
        cu.append(k)
    else:
        m=count[i]
        n=cu[i-1]
        k=m+n
        cu.append(k)
    i=i+1
    
    


#l1



tf1=tf/2

print "total freq ",tf1
i=0

c=24
def find(x,y):
    jk=0
    le=len(cu)
    while(jk<le):
        if cu[jk] < y :
            jk+=1
        else:
            return jk

        


d=find(cu,tf1)

print " indx is ",d    #returned array index 
loc_m=d+1          
print loc_m
L1=pr[2*loc_m-2]     #location of mimium medium grouped data indx
print "me ",L1





n1=(tf+1)/2

fm=count[d]

fc=cu[d-1]

c=abs(pr[1]-pr[0])

d=(n1-fc)/fm
median= L1+d*c

print "meadian is ",median



#Mode of Group Data


count
#find biggest freq  index

i=0
dcount=[]
while(i<len(count)):
    
    dcount.append(int(count[i]))
        
    
    i=i+1
print dcount  
print type(dcount)
#print numbers[x]

c=dcount
print c
x = 1
z=0

while x<len(c):
    
    if c[x] >c[z]:
        z=x
    
    x=x+1
    
if len(c) == z: 
    print " _ _^--^ _ _"
else: 
    print "highest fre__ loc " ,z  ,"value  ",c[z]
    
    
    
#find l1 for  modal class freq
#print z


d=z

print " indx is ",d    #returned array index 
loc_m=d+1          
print loc_m
L1=pr[2*loc_m-2]     #location of mimium medium grouped data indx
print " ",L1


c=abs(pr[1]-pr[0])

print c
print dcount

d1=abs(float(dcount[3]-dcount[2]))
d2=abs(float(dcount[3]-dcount[4]))

d=float(d1/(d1+d2))
print (d)

mode=L1+c*d

print "mode is ",mode

import numpy as np 

ma_av=np.average(mark)
print ma_av

i=0
ss=0
while i<len(mark):
    ss=ss+count[i]* (mark[i]-ma_av)**2
    
    i=i+1
    
ss=ss/len(mark)
    
sigma=sqrt(ss) 
print "standard deviation is ",sigma

v=sigma**2
print "variance ",v





i=0
su=0
while i<len(count):
    su=su+count[i]*(mark[i]-am)
    
    i=i+1
    
ss=su/sum(mark)
    

print "first central moment about mean ",ss



def cm(mark,count,refvalue,nth):
    i=0
    su=0
    am=refvalue
    while i<len(count):
        su=su+count[i]*(mark[i]-am)**nth
    
        i=i+1
    
    ss=su/sum(mark)
    

    print ss
        
        

refvalue=4
nth=3
cm(mark,count,refvalue,nth)
# Out:
# 30.0
# [35.0, 45.0, 55.0, 65.0, 75.0, 85.0, 95.0]
# [10.0, 15.0, 20.0, 25.0, 20.0, 7.0, 3.0]
# geometric mean is  59.3052094694
# arthic. mean is  61.3
# total frequency  100.0
# harmonic mean is  57.2115789556
# total freq  50.0
#  indx is  3
# 4
# me  60.0
# meadian is  62.2
# [10, 15, 20, 25, 20, 7, 3]
# <type 'list'>
# [10, 15, 20, 25, 20, 7, 3]
# highest fre__ loc  3 value   25
#  indx is  3
# 4
#   60.0
# 10.0
# [10, 15, 20, 25, 20, 7, 3]
# 0.5
# mode is  65.0
# 65.0
# standard deviation is  59.160797831
# variance  3500.0
# first central moment about mean  7.18350897692e-16
# 50106.1318681
