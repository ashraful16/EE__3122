# %%
import numpy as np
A = np.array([[25,5,1], [64,8,1], [144,12,1]], dtype='float')
Ab=A
bcb=A
n = len(Ab)
#print n
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = a[i] / b[i]
        Ab[j] = a - m * b
        #print 'j '," = ",j, b," = ",   m

print "upper  \n  "
print Ab

L=Ab
# Out:
# upper
#
# [[25.        5.        1.      ]
#  [ 0.        1.875     0.609375]
#  [ 0.        0.        0.078125]]

# %%
A = np.array([[25,5,1], [64,8,1], [144,12,1]], dtype='float')


bb=A

n = len(bb)
for i in range(n - 1, -1, -1):
    #print Ab[i],"  /  " , Ab[i, i] ," idx" ,i,i
    bb[i] = bb[i] / bb[i, i]
    c = bb[i]
    for j in range(i - 1, -1, -1):
        d= bb[j]
        m = c[i] / d[i]
        bb[j] = (c - m * d)
    
print "lower " ,"  \n  "
print bb

U=bb
# Out:
# lower
#
# [[  1.   0.   0.]
#  [ 20.   1.   0.]
#  [144.  12.   1.]]

# %%
print np.matmul(U,L)
# Out:
# [[2.50000000e+01 5.00000000e+00 1.00000000e+00]
#  [5.00000000e+02 1.01875000e+02 2.06093750e+01]
#  [3.60000000e+03 7.42500000e+02 1.51390625e+02]]

# %%
# Python3 program to print Lower 
# triangular and Upper triangular 
# matrix of an array 

# Function to form lower triangular 
# matrix 
def lower(matrix, row, col): 

	
	for i in range(0, row): 
	
		for j in range(0, col): 
		
			if (i < j): 
			
				print("0", end = " "); 
			
			else: 
				print(matrix[i][j], 
					end = " " ); 
		
		print(" "); 
	
# Function to form upper triangular marix 
def upper(matrix, row, col): 

	for i in range(0, row): 
	
		for j in range(0, col): 
		
			if (i > j): 
				print("0", end = " "); 
			
			else: 
				print(matrix[i][j], end = " " ); 
		
		print(" "); 

# Driver Code 
matrix = [[1, 2, 3], 
		[4, 5, 6], 
		[7, 8, 9]]; 
row = 3; 
col = 3; 
	
print("Lower triangular matrix: "); 
lower(matrix, row, col); 
	
print("Upper triangular matrix: "); 
upper(matrix, row, col); 
		
# This code is contributed by 
# Shivi_Aggarwal
# Out:
#   File "<ipython-input-16-e5b53e2f53ed>", line 18
#     print("0", end = " ");
#                    ^
# SyntaxError: invalid syntax

# %%
import numpy as np

Ab=np.array([[25,5,1], [64,8,1], [144,12,1]],dtype='float')
aaa=Ab
n = len(Ab)
#print n
me=[]
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = float(a[i] / b[i])
        me.append(1/m)
        Ab[j] = b - (1/m) * a
        #print 'j '," = ",j, b," = ",   m

print "upper  \n  "
print Ab
print me
ccc=Ab
np.save('d1', ccc) 
#for i in range(n):
#    for j in range(n):
#       print i,j
 #       print Ab[i][j]
        
k=0            
for i in range(n):
    for j in range(n):
        if (i > j) :
            ccc[i][j]=me[k]
            k=k+1
        else:
            continue
#print ccc 

for i in range(n):
    for j in range(n):
        if (i == j) :
            ccc[i][j]=1
            
        else:
            continue
            
            
#print ccc

for i in range(n):
    for j in range(n):
        if (i < j) :
            ccc[i][j]=0
            
        else:
            continue
print " lower is   \n " ,ccc
# Out:
# upper
#
# [[25.    5.    1.  ]
#  [ 0.   -4.8  -1.56]
#  [ 0.    0.    0.7 ]]
# [2.56, 5.76, 3.4999999999999987]
#  lower is
#   [[1.   0.   0.  ]
#  [2.56 1.   0.  ]
#  [5.76 3.5  1.  ]]

# %%
a = np.load('d1.npy')
print a
# Out:
# [[25.    5.    1.  ]
#  [ 0.   -4.8  -1.56]
#  [ 0.    0.    0.7 ]]

# %%
 
a = np.ones(1000) # create an array of 1000 1's for the example  
np.save('d1', a)

# %%
a = np.load('d1.npy')

# %%
#print a

# %%
import numpy as np

Ab=np.array([[25,5,1], [64,8,1], [144,12,1]],dtype='float')
np.save('d1', Ab) 
aaa=Ab
n = len(Ab)
#print n
me=[]
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = float(a[i] / b[i])
        me.append(1/m)
        Ab[j] = b - (1/m) * a
        #print 'j '," = ",j, b," = ",   m

#print "upper  \n  "
#print Ab
#print me


ccc=Ab
np.save('d2', Ab) 

#for i in range(n):
#    for j in range(n):
#       print i,j
 #       print Ab[i][j]
        
k=0            
for i in range(n):
    for j in range(n):
        if (i > j) :
            ccc[i][j]=me[k]
            k=k+1
        else:
            continue
#print ccc 

for i in range(n):
    for j in range(n):
        if (i == j) :
            ccc[i][j]=1
            
        else:
            continue
        
            
       
            
#print ccc

for i in range(n):
    for j in range(n):
        if (i < j) :
            ccc[i][j]=0
            
        else:
            continue
#print " lower is   \n " ,ccc 

np.save('d3', ccc) 

a1 = np.load('d1.npy')                                   
a2 = np.load('d2.npy')
a3=np.load('d3.npy')


x=[1,0,0]


LU = np.linalg.solve(a3,x) 
p=LU
#for d in LU:
 #   print d
    
    
    
##final solution 

LU = np.linalg.solve(a2,p) 
p1=LU
for d in LU:
    print d
# Out:
# 0.0476190476190477
# -0.952380952380954
# 4.571428571428577

# %%
import numpy as np

Ab=np.array([[25,5,1], [64,8,1], [144,12,1]],dtype='float')
np.save('d1', Ab) 
aaa=Ab
n = len(Ab)
#print n
me=[]
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = float(a[i] / b[i])
        me.append(1/m)
        Ab[j] = b - (1/m) * a
        #print 'j '," = ",j, b," = ",   m

#print "upper  \n  "
#print Ab
#print me


ccc=Ab
np.save('d2', Ab) 

#for i in range(n):
#    for j in range(n):
#       print i,j
 #       print Ab[i][j]
        
k=0            
for i in range(n):
    for j in range(n):
        if (i > j) :
            ccc[i][j]=me[k]
            k=k+1
        else:
            continue
#print ccc 

for i in range(n):
    for j in range(n):
        if (i == j) :
            ccc[i][j]=1
            
        else:
            continue
        
            
       
            
#print ccc

for i in range(n):
    for j in range(n):
        if (i < j) :
            ccc[i][j]=0
            
        else:
            continue
#print " lower is   \n " ,ccc 

np.save('d3', ccc) 

a1 = np.load('d1.npy')                                   
a2 = np.load('d2.npy')
a3=np.load('d3.npy')


x=[0,1,0]


LU = np.linalg.solve(a3,x) 
p=LU
#for d in LU:
 #   print d
    
    
    
##final solution 

LU = np.linalg.solve(a2,p) 
p2=LU
for d in LU:
    print d
# Out:
# -0.08333333333333356
# 1.4166666666666698
# -5.00000000000001

# %%
import numpy as np

Ab=np.array([[25,5,1], [64,8,1], [144,12,1]],dtype='float')
np.save('d1', Ab) 
aaa=Ab
n = len(Ab)
#print n
me=[]
for i in range(n):
    a = Ab[i]
    #print a,"  ",n

    for j in range(i + 1, n):
        b = Ab[j]
        m = float(a[i] / b[i])
        me.append(1/m)
        Ab[j] = b - (1/m) * a
        #print 'j '," = ",j, b," = ",   m

#print "upper  \n  "
#print Ab
#print me


ccc=Ab
np.save('d2', Ab) 

#for i in range(n):
#    for j in range(n):
#       print i,j
 #       print Ab[i][j]
        
k=0            
for i in range(n):
    for j in range(n):
        if (i > j) :
            ccc[i][j]=me[k]
            k=k+1
        else:
            continue
#print ccc 

for i in range(n):
    for j in range(n):
        if (i == j) :
            ccc[i][j]=1
            
        else:
            continue
        
            
       
            
#print ccc

for i in range(n):
    for j in range(n):
        if (i < j) :
            ccc[i][j]=0
            
        else:
            continue
#print " lower is   \n " ,ccc 

np.save('d3', ccc) 

a1 = np.load('d1.npy')                                   
a2 = np.load('d2.npy')
a3=np.load('d3.npy')


x=[0,0,1]


LU = np.linalg.solve(a3,x) 
p=LU
#for d in LU:
 #   print d
    
    
    
##final solution 

LU = np.linalg.solve(a2,p) 
p3=LU
for d in LU:
    print d
# Out:
# 0.0357142857142858
# -0.46428571428571536
# 1.428571428571432

# %%
zz=np.array([[p1],[p2],[p3]])
fm=zz.T

# %%
print fm

print a1

c=np.matmul(fm,a1)
# Out:
# [[[ 0.04761905 -0.08333333  0.03571429]]
#
#  [[-0.95238095  1.41666667 -0.46428571]]
#
#  [[ 4.57142857 -5.          1.42857143]]]
# [[ 25.   5.   1.]
#  [ 64.   8.   1.]
#  [144.  12.   1.]]
